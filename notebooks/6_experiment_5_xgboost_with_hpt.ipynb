# %%
# !pip install mlflow boto3 awscli optuna xgboost imbalanced-learn

# %%
# !aws configure

# %%
# !aws configure

# %%
import mlflow
# Step 2: Set up the MLflow tracking server
mlflow.set_tracking_uri("http://ec2-56-228-26-202.eu-north-1.compute.amazonaws.com:5000/")

# %%
# Set or create an experiment
mlflow.set_experiment("Exp 5 - ML Algos with HP Tuning")
# Out:
# <Experiment: artifact_location='s3://mlflow-bucket-2004/121751411409575918', creation_time=1761611853050, experiment_id='121751411409575918', last_update_time=1761611853050, lifecycle_stage='active', name='Exp 5 - ML Algos with HP Tuning', tags={'mlflow.experimentKind': 'custom_model_development'}>

# %%
import optuna
import mlflow
import mlflow.sklearn
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import RandomForestClassifier
from imblearn.over_sampling import SMOTE
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
df = pd.read_csv('reddit_preprocessing.csv').dropna()
df.shape
# Out:
# (36662, 2)

# %%
# Step 1: Remap the class labels from [-1, 0, 1] to [2, 0, 1]
df['category'] = df['category'].map({-1: 2, 0: 0, 1: 1})

# Step 2: Remove rows where the target labels (category) are NaN
df = df.dropna(subset=['category'])

ngram_range = (1, 3)  # Bigram setting
max_features = 10000  # Set max_features to 1000 for TF-IDF

# Step 4: Train-test split before vectorization and resampling
X_train, X_test, y_train, y_test = train_test_split(df['clean_comment'], df['category'], test_size=0.2, random_state=42, stratify=df['category'])

# Step 2: Vectorization using TF-IDF, fit on training data only
vectorizer = TfidfVectorizer(ngram_range=ngram_range, max_features=max_features)
X_train_vec = vectorizer.fit_transform(X_train)  # Fit on training data
X_test_vec = vectorizer.transform(X_test)  # Transform test data

smote = SMOTE(random_state=42)
X_train_vec, y_train = smote.fit_resample(X_train_vec, y_train)

# Function to log results in MLflow
def log_mlflow(model_name, model, X_train, X_test, y_train, y_test):
    with mlflow.start_run():
        # Log model type
        mlflow.set_tag("mlflow.runName", f"{model_name}_SMOTE_TFIDF_Trigrams")
        mlflow.set_tag("experiment_type", "algorithm_comparison")

        # Log algorithm name as a parameter
        mlflow.log_param("algo_name", model_name)

        # Train model
        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)

        # Log accuracy
        accuracy = accuracy_score(y_test, y_pred)
        mlflow.log_metric("accuracy", accuracy)

        # Log classification report
        classification_rep = classification_report(y_test, y_pred, output_dict=True)
        for label, metrics in classification_rep.items():
            if isinstance(metrics, dict):
                for metric, value in metrics.items():
                    mlflow.log_metric(f"{label}_{metric}", value)

        # Log the model
        mlflow.sklearn.log_model(model, f"{model_name}_model")


# Step 6: Optuna objective function for XGBoost
def objective_xgboost(trial):
    n_estimators = trial.suggest_int('n_estimators', 50, 300)
    learning_rate = trial.suggest_float('learning_rate', 1e-4, 1e-1, log=True)
    max_depth = trial.suggest_int('max_depth', 3, 10)

    model = XGBClassifier(n_estimators=n_estimators, learning_rate=learning_rate, max_depth=max_depth, random_state=42)
    return accuracy_score(y_test, model.fit(X_train_vec, y_train).predict(X_test_vec))


# Step 7: Run Optuna for XGBoost, log the best model only
def run_optuna_experiment():
    study = optuna.create_study(direction="maximize")
    study.optimize(objective_xgboost, n_trials=30)

    # Get the best parameters and log only the best model
    best_params = study.best_params
    best_model = XGBClassifier(n_estimators=best_params['n_estimators'], learning_rate=best_params['learning_rate'], max_depth=best_params['max_depth'], random_state=42)

    # Log the best model with MLflow, passing the algo_name as "xgboost"
    log_mlflow("XGBoost", best_model, X_train_vec, X_test_vec, y_train, y_test)

# Run the experiment for XGBoost
run_optuna_experiment()
# Out:
# [I 2025-10-29 12:07:46,403] A new study created in memory with name: no-name-a33d1fd6-a304-497b-b7d4-83b412505306
# [I 2025-10-29 12:08:02,077] Trial 0 finished with value: 0.49324969316787126 and parameters: {'n_estimators': 226, 'learning_rate': 0.0001546571355491966, 'max_depth': 3}. Best is trial 0 with value: 0.49324969316787126.
# [I 2025-10-29 12:08:30,599] Trial 1 finished with value: 0.5540706395745261 and parameters: {'n_estimators': 107, 'learning_rate': 0.00043129970734722236, 'max_depth': 6}. Best is trial 1 with value: 0.5540706395745261.
# [I 2025-10-29 12:10:56,396] Trial 2 finished with value: 0.6060275467066685 and parameters: {'n_estimators': 280, 'learning_rate': 0.0014777024775362916, 'max_depth': 8}. Best is trial 2 with value: 0.6060275467066685.
# [I 2025-10-29 12:11:35,883] Trial 3 finished with value: 0.5109777717168962 and parameters: {'n_estimators': 284, 'learning_rate': 0.0002884304544439505, 'max_depth': 3}. Best is trial 2 with value: 0.6060275467066685.
# [I 2025-10-29 12:12:11,239] Trial 4 finished with value: 0.5702986499386336 and parameters: {'n_estimators': 216, 'learning_rate': 0.0032108764449112473, 'max_depth': 4}. Best is trial 2 with value: 0.6060275467066685.
# [I 2025-10-29 12:13:18,062] Trial 5 finished with value: 0.6368471294149735 and parameters: {'n_estimators': 81, 'learning_rate': 0.008037075523556658, 'max_depth': 10}. Best is trial 5 with value: 0.6368471294149735.
# [I 2025-10-29 12:13:36,988] Trial 6 finished with value: 0.6533478794490659 and parameters: {'n_estimators': 133, 'learning_rate': 0.025460826362147373, 'max_depth': 4}. Best is trial 6 with value: 0.6533478794490659.
# [I 2025-10-29 12:14:00,728] Trial 7 finished with value: 0.5367516705304787 and parameters: {'n_estimators': 161, 'learning_rate': 0.00042649952718337817, 'max_depth': 4}. Best is trial 6 with value: 0.6533478794490659.
# [I 2025-10-29 12:15:01,423] Trial 8 finished with value: 0.5405700259102687 and parameters: {'n_estimators': 233, 'learning_rate': 0.00011790561804496048, 'max_depth': 5}. Best is trial 6 with value: 0.6533478794490659.
# [I 2025-10-29 12:15:22,195] Trial 9 finished with value: 0.5497068048547661 and parameters: {'n_estimators': 87, 'learning_rate': 0.0024933332758753247, 'max_depth': 5}. Best is trial 6 with value: 0.6533478794490659.
# [I 2025-10-29 12:16:33,295] Trial 10 finished with value: 0.7608073094231556 and parameters: {'n_estimators': 150, 'learning_rate': 0.07630544211296966, 'max_depth': 8}. Best is trial 10 with value: 0.7608073094231556.
# [I 2025-10-29 12:17:35,212] Trial 11 finished with value: 0.7681712805127506 and parameters: {'n_estimators': 146, 'learning_rate': 0.09591098764040487, 'max_depth': 8}. Best is trial 11 with value: 0.7681712805127506.
# [I 2025-10-29 12:18:48,132] Trial 12 finished with value: 0.7707623073776081 and parameters: {'n_estimators': 171, 'learning_rate': 0.09656725832786056, 'max_depth': 8}. Best is trial 12 with value: 0.7707623073776081.
# [I 2025-10-29 12:20:00,790] Trial 13 finished with value: 0.7734897040774581 and parameters: {'n_estimators': 196, 'learning_rate': 0.09066799435837404, 'max_depth': 8}. Best is trial 13 with value: 0.7734897040774581.
# [I 2025-10-29 12:22:30,378] Trial 14 finished with value: 0.7107595799809082 and parameters: {'n_estimators': 187, 'learning_rate': 0.021837688229716646, 'max_depth': 10}. Best is trial 13 with value: 0.7734897040774581.
# [I 2025-10-29 12:23:45,118] Trial 15 finished with value: 0.7130778671757807 and parameters: {'n_estimators': 195, 'learning_rate': 0.029977410740526293, 'max_depth': 7}. Best is trial 13 with value: 0.7734897040774581.
# [I 2025-10-29 12:24:28,281] Trial 16 finished with value: 0.6783035592526933 and parameters: {'n_estimators': 53, 'learning_rate': 0.045593338278368506, 'max_depth': 9}. Best is trial 13 with value: 0.7734897040774581.
# [I 2025-10-29 12:26:12,693] Trial 17 finished with value: 0.6555297968089459 and parameters: {'n_estimators': 246, 'learning_rate': 0.008343945817801337, 'max_depth': 7}. Best is trial 13 with value: 0.7734897040774581.
# [I 2025-10-29 12:28:09,202] Trial 18 finished with value: 0.6803491067775808 and parameters: {'n_estimators': 189, 'learning_rate': 0.0133732091882238, 'max_depth': 9}. Best is trial 13 with value: 0.7734897040774581.
# [I 2025-10-29 12:30:04,281] Trial 19 finished with value: 0.7683076503477431 and parameters: {'n_estimators': 250, 'learning_rate': 0.05180575860069603, 'max_depth': 9}. Best is trial 13 with value: 0.7734897040774581.
# [I 2025-10-29 12:30:40,542] Trial 20 finished with value: 0.5923905632074186 and parameters: {'n_estimators': 112, 'learning_rate': 0.005660864848106114, 'max_depth': 6}. Best is trial 13 with value: 0.7734897040774581.
# [I 2025-10-29 12:32:31,143] Trial 21 finished with value: 0.7700804582026456 and parameters: {'n_estimators': 260, 'learning_rate': 0.052696435660537444, 'max_depth': 9}. Best is trial 13 with value: 0.7734897040774581.
# [I 2025-10-29 12:34:04,550] Trial 22 finished with value: 0.783853811536888 and parameters: {'n_estimators': 300, 'learning_rate': 0.09690952133175826, 'max_depth': 8}. Best is trial 22 with value: 0.783853811536888.
# [I 2025-10-29 12:35:04,223] Trial 23 finished with value: 0.7673530615027956 and parameters: {'n_estimators': 208, 'learning_rate': 0.07857786388859345, 'max_depth': 7}. Best is trial 22 with value: 0.783853811536888.
# [I 2025-10-29 12:36:15,605] Trial 24 finished with value: 0.7721260057275331 and parameters: {'n_estimators': 168, 'learning_rate': 0.09926789949317587, 'max_depth': 8}. Best is trial 22 with value: 0.783853811536888.
# [I 2025-10-29 12:38:35,231] Trial 25 finished with value: 0.7156688940406382 and parameters: {'n_estimators': 293, 'learning_rate': 0.018115528765221704, 'max_depth': 8}. Best is trial 22 with value: 0.783853811536888.
# [I 2025-10-29 12:39:21,481] Trial 26 finished with value: 0.7017591708714033 and parameters: {'n_estimators': 128, 'learning_rate': 0.03672541312543286, 'max_depth': 7}. Best is trial 22 with value: 0.783853811536888.
# [I 2025-10-29 12:42:29,178] Trial 27 finished with value: 0.7098049911359607 and parameters: {'n_estimators': 270, 'learning_rate': 0.014967540679995029, 'max_depth': 10}. Best is trial 22 with value: 0.783853811536888.
# [I 2025-10-29 12:43:29,915] Trial 28 finished with value: 0.7368062184644757 and parameters: {'n_estimators': 205, 'learning_rate': 0.050427407759916894, 'max_depth': 6}. Best is trial 22 with value: 0.783853811536888.
# [I 2025-10-29 12:45:19,625] Trial 29 finished with value: 0.7732169644074731 and parameters: {'n_estimators': 235, 'learning_rate': 0.06637972509862881, 'max_depth': 9}. Best is trial 22 with value: 0.783853811536888.
# 2025/10/29 12:47:05 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/10/29 12:47:15 INFO mlflow.tracking._tracking_service.client: 🏃 View run XGBoost_SMOTE_TFIDF_Trigrams at: http://ec2-56-228-26-202.eu-north-1.compute.amazonaws.com:5000/#/experiments/121751411409575918/runs/3d549ab8a58b410892984453f7a18a74.
# 2025/10/29 12:47:15 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://ec2-56-228-26-202.eu-north-1.compute.amazonaws.com:5000/#/experiments/121751411409575918.
